# %%
import os
os.environ["DATA_ROOT"] = r"D:\datasets\MRI_Mahdieh_Datasets"

# %%
# !python -m pytest -q
# Out:
# ...........ss                                                            [100%]
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\Lib\site-packages\torch_geometric\llm\utils\backend_utils.py:26
#   C:\Users\Toktam\anaconda3\Lib\site-packages\torch_geometric\llm\utils\backend_utils.py:26: DeprecationWarning: `torch_geometric.distributed` has been deprecated since 2.7.0 and will no longer be maintained. For distributed training, refer to our tutorials on distributed training at https://pytorch-geometric.readthedocs.io/en/latest/tutorial/distributed.html or cuGraph examples at https://github.com/rapidsai/cugraph-gnn/tree/main/python/cugraph-pyg/cugraph_pyg/examples
#     from torch_geometric.distributed import (
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 11 passed, 2 skipped, 1 warning in 5.69s

# %%
# !python -m pytest -q -m contrastive
# Out:
# ...                                                                      [100%]
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\Lib\site-packages\torch_geometric\llm\utils\backend_utils.py:26
#   C:\Users\Toktam\anaconda3\Lib\site-packages\torch_geometric\llm\utils\backend_utils.py:26: DeprecationWarning: `torch_geometric.distributed` has been deprecated since 2.7.0 and will no longer be maintained. For distributed training, refer to our tutorials on distributed training at https://pytorch-geometric.readthedocs.io/en/latest/tutorial/distributed.html or cuGraph examples at https://github.com/rapidsai/cugraph-gnn/tree/main/python/cugraph-pyg/cugraph_pyg/examples
#     from torch_geometric.distributed import (
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 3 passed, 10 deselected, 1 warning in 5.03s

# %%
# !python -m pytest -q -m mil
# Out:
# s                                                                        [100%]
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\Lib\site-packages\torch_geometric\llm\utils\backend_utils.py:26
#   C:\Users\Toktam\anaconda3\Lib\site-packages\torch_geometric\llm\utils\backend_utils.py:26: DeprecationWarning: `torch_geometric.distributed` has been deprecated since 2.7.0 and will no longer be maintained. For distributed training, refer to our tutorials on distributed training at https://pytorch-geometric.readthedocs.io/en/latest/tutorial/distributed.html or cuGraph examples at https://github.com/rapidsai/cugraph-gnn/tree/main/python/cugraph-pyg/cugraph_pyg/examples
#     from torch_geometric.distributed import (
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 1 skipped, 12 deselected, 1 warning in 5.62s

# %%
# !python -m pytest -q -m gnn
# Out:
# s                                                                        [100%]
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\Lib\site-packages\torch_geometric\llm\utils\backend_utils.py:26
#   C:\Users\Toktam\anaconda3\Lib\site-packages\torch_geometric\llm\utils\backend_utils.py:26: DeprecationWarning: `torch_geometric.distributed` has been deprecated since 2.7.0 and will no longer be maintained. For distributed training, refer to our tutorials on distributed training at https://pytorch-geometric.readthedocs.io/en/latest/tutorial/distributed.html or cuGraph examples at https://github.com/rapidsai/cugraph-gnn/tree/main/python/cugraph-pyg/cugraph_pyg/examples
#     from torch_geometric.distributed import (
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 1 skipped, 12 deselected, 1 warning in 5.26s

# %%
import os
os.environ["DATA_ROOT"] = r"D:\datasets\MRI_Mahdieh_Datasets"
# !python -m pytest -q -m contrastive
# Out:
# .s..                                                                     [100%]
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\Lib\site-packages\torch_geometric\llm\utils\backend_utils.py:26
#   C:\Users\Toktam\anaconda3\Lib\site-packages\torch_geometric\llm\utils\backend_utils.py:26: DeprecationWarning: `torch_geometric.distributed` has been deprecated since 2.7.0 and will no longer be maintained. For distributed training, refer to our tutorials on distributed training at https://pytorch-geometric.readthedocs.io/en/latest/tutorial/distributed.html or cuGraph examples at https://github.com/rapidsai/cugraph-gnn/tree/main/python/cugraph-pyg/cugraph_pyg/examples
#     from torch_geometric.distributed import (
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 3 passed, 1 skipped, 10 deselected, 1 warning in 6.10s

# %%
import sys, inspect
sys.path.insert(0, r"C:\Users\Toktam\Documents\github\BrainMRIAnalysis\src")
import ContrastiveLearning.models as m
print([name for name, obj in vars(m).items() if inspect.isclass(obj)])
# Out:
# ['EncoderConfig', 'SmallCNN', 'SimCLR']

# %%
import os
os.environ["DATA_ROOT"] = r"D:\datasets\MRI_Mahdieh_Datasets"
os.environ["CONTRASTIVE_MODEL_CLASS"] = "SimCLR"
# !python -m pytest -q -m contrastive
# Out:
# .s..                                                                     [100%]
# ============================== warnings summary ===============================
# ..\..\..\anaconda3\Lib\site-packages\torch_geometric\llm\utils\backend_utils.py:26
#   C:\Users\Toktam\anaconda3\Lib\site-packages\torch_geometric\llm\utils\backend_utils.py:26: DeprecationWarning: `torch_geometric.distributed` has been deprecated since 2.7.0 and will no longer be maintained. For distributed training, refer to our tutorials on distributed training at https://pytorch-geometric.readthedocs.io/en/latest/tutorial/distributed.html or cuGraph examples at https://github.com/rapidsai/cugraph-gnn/tree/main/python/cugraph-pyg/cugraph_pyg/examples
#     from torch_geometric.distributed import (
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 3 passed, 1 skipped, 10 deselected, 1 warning in 5.95s
